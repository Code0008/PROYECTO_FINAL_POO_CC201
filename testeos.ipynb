# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
base_poblacion_proyectada2021 = pd.read_csv("base_poblacion_proyectada2021.csv", sep=";")
base_poblacion_proyectada2021
# Out:
#         ubigeo_reniec  ubigeo_inei Departamento Provincia    Distrito  \
# 0               21406        21910       ANCASH    SIHUAS  SICSIBAMBA
# 1               21406        21910       ANCASH    SIHUAS  SICSIBAMBA
# 2               21406        21910       ANCASH    SIHUAS  SICSIBAMBA
# 3               21406        21910       ANCASH    SIHUAS  SICSIBAMBA
# 4               21406        21910       ANCASH    SIHUAS  SICSIBAMBA
# ...               ...          ...          ...       ...         ...
# 123679          21507        22007       ANCASH    YUNGAY     SHUPLUY
# 123680          21507        22007       ANCASH    YUNGAY     SHUPLUY
# 123681          21507        22007       ANCASH    YUNGAY     SHUPLUY
# 123682          21507        22007       ANCASH    YUNGAY     SHUPLUY
# 123683          21507        22007       ANCASH    YUNGAY     SHUPLUY
#
#        Edad_Anio Sexo  Cantidad
# 0              6    M         9
# 1          65-69    F        23
# ...

# %%
migracion_internacional = pd.read_excel("caso9_migracion_internacional_clear.xlsx", sheet_name="hoja1", usecols=np.arange(0,21)).dropna().reset_index(drop=True)

#salidas_segun_continente
migracion_internacional
# Out:
#             Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0           Continente      2004.0      2005.0      2006.0      2007.0
# 1                Total   1734696.0   2014480.0   2175763.0   2349590.0
# 2              América   1649855.0   1913046.0   2058271.0   2225729.0
# 3    América del Norte    272793.0    279251.0    249691.0    266488.0
# 4   América del Centro     53377.0     46501.0     54501.0     69755.0
# 5      América del Sur   1323685.0   1587294.0   1754079.0   1889486.0
# 6               Europa     77533.0     94724.0    111478.0    118081.0
# 7                 Asia      5106.0      4530.0      4098.0      4300.0
# 8               África       420.0       286.0       367.0       339.0
# 9              Oceanía       228.0       211.0       270.0       315.0
# 10            Otros 1/      1554.0      1683.0      1279.0       826.0
# 11          Continente      2004.0      2005.0      2006.0      2007.0
# ...

# %%
def columnas():
    lista = np.arange(2004,2024).tolist()
    lista.insert(0, "Contenido")
    return lista
columnas()
# Out:
# ['Contenido',
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021,
#  2022,
#  2023]

# %%
salidas_segun_continente = migracion_internacional.iloc[1:10,:].set_axis(columnas(), axis="columns").reset_index(drop=True)
entradas_segun_continente = migracion_internacional.iloc[12:-1,:].set_axis(columnas(), axis="columns").reset_index(drop=True)
poblacion_estimada = pd.read_csv("crecimiento_estimado_inei.csv", sep=";").iloc[np.arange(24,44), :]

# %%
# 10000 100
# 332 x
# x = 332 * 100 / 100000

# %%
salidas_segun_continente
# Out:
#             Contenido       2004       2005       2006       2007       2008  \
# 0               Total  1734696.0  2014480.0  2175763.0  2349590.0  2423854.0
# 1             América  1649855.0  1913046.0  2058271.0  2225729.0  2290456.0
# 2   América del Norte   272793.0   279251.0   249691.0   266488.0   292195.0
# 3  América del Centro    53377.0    46501.0    54501.0    69755.0    82819.0
# 4     América del Sur  1323685.0  1587294.0  1754079.0  1889486.0  1915442.0
# 5              Europa    77533.0    94724.0   111478.0   118081.0   127149.0
# 6                Asia     5106.0     4530.0     4098.0     4300.0     4722.0
# 7              África      420.0      286.0      367.0      339.0      321.0
# 8             Oceanía      228.0      211.0      270.0      315.0      453.0
#
#         2009     2010     2011       2012  ...       2014       2015  \
# 0  2362457.0  2521267  2680346  2816523.0  ...  3070196.0  3271547.0
# ...

# %%
salidas_segun_continente.iloc[1,0]
# Out:
# 'América'

# %%
porcentajes = [
    0,# Salida
    0,# Entradas

]

valores_america= salidas_segun_continente.iloc[1, list(range(1, len(salidas_segun_continente.columns[1:])))]
valores_total = salidas_segun_continente.iloc[0, list(range(1, len(salidas_segun_continente.columns[1:])))]
porcentajes[0]= (valores_america *100) / valores_total

valores_america= entradas_segun_continente.iloc[1, list(range(1, len(entradas_segun_continente.columns[1:])))]
valores_total = entradas_segun_continente.iloc[0, list(range(1, len(entradas_segun_continente.columns[1:])))]
porcentajes[1]= (valores_america *100) / valores_total
porcentajes
x = ["Salidas", "Entradas"]
for indice, valor in enumerate(porcentajes):
    plt.hist(valor, label=x[indice])
plt.legend()

# %%
valores_continentes = [salidas_segun_continente.iloc[indice, list(range(1, len(salidas_segun_continente.columns[1:])))] for indice in range(1, 9)]
#america_porcentaje, (america_porcentaje*100) / salidas_segun_continente.iloc[0, list(range(1, len(salidas_segun_continente.columns[1:])))] p
porcentaje_cntinentes = [(valores*100)/ salidas_segun_continente.iloc[0, list(range(1, len(salidas_segun_continente.columns[1:])))] for valores in valores_continentes]
plt.figure(figsize=(15,14))
for indice, valor in enumerate(porcentaje_cntinentes):
    plt.hist(porcentaje_cntinentes[indice], edgecolor="black", label=f"{salidas_segun_continente.iloc[indice+1,0]}")
    plt.legend()
plt.xlim(0,100)
# Out:
# (0.0, 100.0)

# %%
entradas_segun_continente
# Out:
#             Contenido       2004       2005       2006       2007       2008  \
# 0               Total  1357292.0  1579195.0  1751043.0  1885212.0  1991241.0
# 1             América  1290078.0  1499691.0  1658031.0  1793783.0  1884454.0
# 2   América del Norte   255381.0   262572.0   236343.0   243809.0   280071.0
# 3  América del Centro    48346.0    46532.0    56302.0    68443.0    86147.0
# 4     América del Sur   986351.0  1190587.0  1365386.0  1481531.0  1518236.0
# 5              Europa    61536.0    75528.0    88314.0    87661.0   103474.0
# 6                Asia     4070.0     2500.0     3025.0     2786.0     2579.0
# 7              África      167.0      112.0      326.0      104.0       82.0
# 8             Oceanía      165.0       99.0      106.0      108.0       64.0
#
#         2009     2010     2011       2012  ...       2014       2015  \
# 0  2023569.0  2221017  2407417  2548403.0  ...  2882829.0  3121039.0
# ...

# %%
continente = salidas_segun_continente.iloc[1:, 0].values
for indice, valor in enumerate(continente):
    print(indice, valor)
# Out:
# 0 América
# 1 América del Norte
# 2 América del Centro
# 3 América del Sur
# 4 Europa
# 5 Asia
# 6 África
# 7 Oceanía

# %%
dataframes = {
        "salidas_segun_continente": migracion_internacional.iloc[1:10,:].set_axis(columnas(), axis="columns").reset_index(drop=True),
        "entradas_segun_continente":migracion_internacional.iloc[12:-1,:].set_axis(columnas(), axis="columns").reset_index(drop=True),
        "poblacion estimada": pd.read_csv("crecimiento_estimado_inei.csv", sep=";").iloc[np.arange(24,44), :]

    }



continentes = dataframes["salidas_segun_continente"]["Contenido"].iloc[1:].values
continentes.tolist
# Out:
# array(['América', 'América del Norte', 'América del Centro',
#        'América del Sur', 'Europa', 'Asia', 'África', 'Oceanía'],
#       dtype=object)

# %%
salidas_segun_continente.iloc[1:, 0]
# Out:
# 1               América
# 2     América del Norte
# 3    América del Centro
# 4       América del Sur
# 5                Europa
# 6                  Asia
# 7                África
# 8               Oceanía
# Name: Contenido, dtype: object

# %%
def graficador_lineas_tendencias( dataframe, ano_A, ano_B, ):
        match dataframe:
            case 'S':
                plt.title(f"SALIDAS")
                dataframe = salidas_segun_continente
            case 'E':
                plt.title(f"ENTRADA")
                dataframe  = entradas_segun_continente
        indices = list(range(dataframe.columns.to_list().index(ano_A), dataframe.columns.to_list().index(ano_B)+1))
        filtracion_datos = dataframe.iloc[1:,indices]
        valores_continentes = [ filtracion_datos.where(dataframe["Contenido"]==valor).dropna().iloc[0]/100 for valor in dataframe.iloc[np.arange(1,9).tolist(), 0]]
        leyenda = []
        for indice, valor in enumerate(valores_continentes, start=1):
            plt.plot(np.arange(ano_A, ano_B+1).tolist(),valor)
            leyenda.append(f"{dataframe.iloc[indice, 0]}")
        plt.legend(leyenda)
        plt.ylabel("Cientos de salida")
        plt.xlabel("Año")

# %%
graficador_lineas_tendencias("S", 2004, 2020)

# %%
graficador_lineas_tendencias("E", 2004, 2020)

# %%
def graficar_barras_continente(continente):
        datos = [
            [salidas_segun_continente.where(salidas_segun_continente["Contenido"]==continente).dropna()[2023] /100,       
             entradas_segun_continente.where(entradas_segun_continente["Contenido"]==continente).dropna()[2023] /100],
            ["Salidas", "Entradas" ],
            ["#C70039", "#DAF7A6"]
        ]
        for indice in range(len(datos)-1):
           plt.bar(datos[1][indice], datos[0][indice], color=datos[2][indice])
        plt.legend(["Salida", "Entrada"])
        plt.ylabel("Cientos")

# %%
graficar_barras_continente("América")

# %%
def graficar_barras_continente_diago( continente):
        #datos = [salidas_segun_continente.where(salidas_segun_continente["Contenido"]=="América").dropna()[2021] , 
                         # entradas_segun_continente.where(entradas_segun_continente["Contenido"]=="América").dropna()[2021]]
        datos = [salidas_segun_continente[2021][salidas_segun_continente["Contenido"]==continente].to_list()[0]/100, 
                          entradas_segun_continente[2021][entradas_segun_continente["Contenido"]==continente].to_list()[0]/100]
        #plt.barh("Salidas",  salidas_continente[ano], )
        #plt.barh("Entradas",  entradas_continente[ano])
        #plt.barh(np.array(["Salidas","Entradas" ]),  datos)
        #plt.barh(y=["xd","xdd"], width=datos)
        plt.barh(y=["Salidas", "Entradas"], width=datos, color=   ["#C70039", "#DAF7A6"])
        plt.xlabel(f"Cantidad en cientos")

# %%
graficar_barras_continente_diago("América")

# %%
1 and 2 in [2,34,45,1]
# Out:
# True

# %%
x = "E:2004:2023"
ano_A=0
ano_B= 0
dataframe_opcion =""
dataframe_opcion,ano_A, ano_B = tuple(x.split(":"))
dataframe_opcion,ano_B, ano_A
# Out:
# ('E', '2023', '2004')

# %%
str.upp

# %%
migracion_internacional = pd.read_excel("caso9_migracion_internacional_clear.xlsx", sheet_name="hoja1", usecols=np.arange(0,21)).dropna().reset_index(drop=True)
dataframes = {
        "salidas_segun_continente": migracion_internacional.iloc[1:10,:].set_axis(columnas(), axis="columns").reset_index(drop=True),
        "entradas_segun_continente":migracion_internacional.iloc[12:-1,:].set_axis(columnas(), axis="columns").reset_index(drop=True),
        "poblacion_estimada": pd.read_csv("crecimiento_estimado_inei.csv", sep=";").iloc[np.arange(24,44), :]


    }

# %%
dataframes["poblacion_estimada"]["Total"].apply(lambda x: int(x.replace('.','')))
# Out:
# 24    27492091
# 25    27722342
# 26    27934784
# 27    28122158
# 28    28300372
# 29    28485319
# 30    28692915
# 31    28905725
# 32    29113162
# 33    29341346
# 34    29616414
# 35    29964499
# 36    30422831
# 37    30973992
# 38    31562130
# 39    32131400
# 40    32625948
# 41    33035304
# 42    33396698
# 43    33725844
# Name: Total, dtype: int64

# %%
indice_continente = 1
valores = [
        [(dataframes["salidas_segun_continente"].iloc[indice_continente, list(range(1, len(dataframes["salidas_segun_continente"].columns[1:])))] * 100) / dataframes["salidas_segun_continente"].iloc[0, list(range(1,len(dataframes["salidas_segun_continente"].columns[1:])))],"Salidas"],
        [(dataframes["entradas_segun_continente"].iloc[indice_continente, list(range(1, len(dataframes["entradas_segun_continente"].columns[1:])))] * 100) / dataframes["entradas_segun_continente"].iloc[0, list(range(1,len(dataframes["entradas_segun_continente"].columns[1:])))], "Entradas"]     
        ] 


plt.hist(valores[0][0])
plt.hist(valores[1][0])
# Out:
# (array([2., 0., 0., 0., 0., 1., 0., 7., 3., 6.]),
#  array([89.25794851, 89.84717372, 90.43639893, 91.02562414, 91.61484935,
#         92.20407456, 92.79329977, 93.38252498, 93.97175019, 94.5609754 ,
#         95.15020061]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(15,9))

plt.scatter(dataframes["poblacion_estimada"]["Total"].apply(lambda x: int(x.replace('.',''))) /100 , dataframes["salidas_segun_continente"].iloc[0, 1:] /10 )
plt.ylabel("Salidas en decenas", fontdict={"color": "orange",
                                           "fontsize":22, 
                                           "fontweight": "bold"})
plt.xlabel("estimacion de poblacion en cientos", fontdict={"color": "green",
                                           "fontsize":22, 
                                           "fontweight": "bold"})

plt.title(f"No se puede representaer una buena regresion lineal debido a que falta lineabilidad en los datos :v")
# Out:
# Text(0.5, 1.0, 'No se puede representaer una buena regresion lineal debido a que falta lineabilidad en los datos :v')
